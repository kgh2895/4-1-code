# %%
import matplotlib
import numpy as np

# %%
#test 
print('hello')
# Out:
# hello

# %%
x = np.array([1.0, 2.0, 3.0])
print(x)
type(x)
# Out:
# [1. 2. 3.]
# numpy.ndarray

# %%
x = np.array([1.0, 2.0, 3.0])
y = np.array([4.0, 5.0, 6.0])
x + y
x - y
x * y
x / y
# Out:
# array([0.25, 0.4 , 0.5 ])

# %%
A = np.array([[1,2],[3,4]])
print(A)
print(A.shape)
print(A.dtype)
# Out:
# [[1 2]
#  [3 4]]
# (2, 2)
# int32

# %%
B = np.array([[3, 0], [0, 6]])
print(A + B )
print(A*B)
# Out:
# [[ 4  2]
#  [ 3 10]]
# [[ 3  0]
#  [ 0 24]]

# %%
X = np.array([[51, 55], [14, 19], [0, 4]])
print(X)

for row in X:
    print(row)
# Out:
# [[51 55]
#  [14 19]
#  [ 0  4]]
# [51 55]
# [14 19]
# [0 4]

# %%
x, y = map(int, input().split())
if x*y == 1:
    z = 1
else: z = 0 
print(z)
# Out:
# 0
